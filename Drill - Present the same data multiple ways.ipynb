# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %matplotlib inline
df = pd.read_csv('listings.csv')
df_cal = pd.read_csv('/Users/zhangtong/Downloads/calendar.csv')
df.head()
# Out:
#          id                                           name   host_id  \
# 0  10988680               Simple, new, clean accommodation   2448592
# 1   8053481            Spacious 2BR/2BATH w/Shared Kitchen  14419919
# 2  14011173  Private room - Victorian House in the Mission   4901696
# 3  16142131           Spacious 1BR in the Mission District  50491424
# 4   9080622             Edwardian flat in heart of Mission  46158576
#
#          host_name  neighbourhood_group neighbourhood   latitude   longitude  \
# 0           Georgy                  NaN       Mission  37.754184 -122.406514
# 1  David & Barbara                  NaN       Mission  37.754166 -122.421534
# 2           Donald                  NaN       Mission  37.758506 -122.406152
# 3          Avishai                  NaN       Mission  37.756549 -122.422025
# 4            Cindy                  NaN       Mission  37.760051 -122.421352
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df_cal.head()
# Out:
#    listing_id        date available price
# 0    10988680  2018-04-01         f   NaN
# 1    10988680  2018-03-31         f   NaN
# 2    10988680  2018-03-30         f   NaN
# 3    10988680  2018-03-29         f   NaN
# 4    10988680  2018-03-28         f   NaN

# %%
print('Line plots show prices')
plt.plot(df['price'])
plt.show()
print('Scatterplots show the relationship between two variables.')
plt.scatter(df['number_of_reviews'],df['price'])
plt.show()

print('Histograms show the distribution of the dataset and any outliers.')
plt.hist(df['price'],100,[0,2000])

# plt.xlim(0,4000)
plt.show()


print('Boxplots are used to compare groups and to identify differences in variance, as well as outliers.')
plt.boxplot([df['price']])
plt.ylim(0, 1000)
# Out:
# Line plots show prices
# Scatterplots show the relationship between two variables.
# Histograms show the distribution of the dataset and any outliers.
# Boxplots are used to compare groups and to identify differences in variance, as well as outliers.
# (0, 1000)

# %%
sns.pairplot(df[['price', 'number_of_reviews', 'reviews_per_month','availability_365']].dropna())

# %%
df_cal_a = df_cal.dropna() 
df_cal_a['price'] = df_cal_a['price'].replace({'$':''}, regex = True)
df_cal_a['price']  = df_cal_a['price'] .replace({',':''}, regex = True)
df_cal_a['price']  = pd.to_numeric(price) # convert string to float
min_price = price.min()
print(min_price)
print(df_cal_a.loc[df_cal_a['price'] == min_price])
# Out:
# /Users/zhangtong/Applications/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/zhangtong/Applications/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# 10.0
#          listing_id        date available  price
# 335345     16792748  2017-06-30         t   10.0
# 335346     16792748  2017-06-29         t   10.0
# ...

# %%
df_cal.groupby(['date', 'available']).size().sort_values()
# df_busy = pd.DataFrame({'date': df_cal.index, 'available': df_cal.values})
# df_busy.head()
# Out:
# date        available
# 2017-04-01  t               7
#             f              72
# 2017-04-02  t            1304
# 2017-04-03  t            1613
# 2017-04-04  t            1691
# 2017-04-05  t            1819
# 2017-04-06  t            1946
# 2017-04-07  t            2069
# 2017-04-08  t            2166
# 2017-04-09  t            2425
# 2017-04-13  t            2462
# 2017-04-12  t            2466
# 2017-04-14  t            2476
# 2017-04-10  t            2489
# 2017-04-11  t            2517
# 2017-04-15  t            2538
# 2017-07-22  t            2604
# 2017-07-23  t            2630
# 2017-07-21  t            2650
# 2017-07-24  t            2650
# 2017-10-06  t            2672
# 2017-07-20  t            2676
# 2017-10-07  t            2677
# 2017-10-02  t            2679
# 2017-08-11  t            2680
# 2017-09-30  t            2682
# 2017-10-05  t            2688
# 2017-10-01  t            2689
# 2017-10-08  t            2690
# 2017-09-29  t            2691
# ...
