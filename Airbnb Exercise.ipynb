# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from IPython.display import HTML, display
df = pd.read_csv('listings.csv')
df.head()
# Out:
#          id                                           name   host_id  \
# 0  10988680               Simple, new, clean accommodation   2448592
# 1   8053481            Spacious 2BR/2BATH w/Shared Kitchen  14419919
# 2  14011173  Private room - Victorian House in the Mission   4901696
# 3  16142131           Spacious 1BR in the Mission District  50491424
# 4   9080622             Edwardian flat in heart of Mission  46158576
#
#          host_name  neighbourhood_group neighbourhood   latitude   longitude  \
# 0           Georgy                  NaN       Mission  37.754184 -122.406514
# 1  David & Barbara                  NaN       Mission  37.754166 -122.421534
# 2           Donald                  NaN       Mission  37.758506 -122.406152
# 3          Avishai                  NaN       Mission  37.756549 -122.422025
# 4            Cindy                  NaN       Mission  37.760051 -122.421352
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df_cal = pd.read_csv('/Users/zhangtong/Downloads/calendar.csv')

df_cal['price'] = df_cal['price'].str.replace('$', '')
df_cal['price'] = df_cal['price'].str.replace(',', '')
df_cal['price'] = df_cal['price'].astype(float)
df_cal['date'] = pd.to_datetime(df_cal['date'])
df_cal['year'], df_cal['month'] = df_cal['date'].dt.year, df_cal['date'].dt.month
display(df_cal.head())
df_cal.groupby(['year', 'month']).mean()
# Out:
#    listing_id       date available  price  year  month
# 0    10988680 2018-04-01         f    NaN  2018      4
# 1    10988680 2018-03-31         f    NaN  2018      3
# 2    10988680 2018-03-30         f    NaN  2018      3
# 3    10988680 2018-03-29         f    NaN  2018      3
# 4    10988680 2018-03-28         f    NaN  2018      3
#             listing_id       price
# year month
# 2017 4         8917754  243.111014
#      5         8917499  238.164474
#      6         8917499  242.800912
#      7         8917499  252.810193
#      8         8917499  248.795583
#      9         8917499  241.456943
#      10        8917499  244.432373
#      11        8917499  246.030944
#      12        8917499  238.675542
# 2018 1         8917499  240.797485
#      2         8917499  237.454662
#      3         8917499  236.794912
#      4         8910029  233.419668

# %%
sns.boxplot(x='room_type', y='price',data=df)
plt.show()
